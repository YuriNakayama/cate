# %%
import mlflow
import pandas as pd

# %%
REMOTE_TRACKING_URI = "http://ec2-44-217-145-52.compute-1.amazonaws.com:5000"
experiment_name = "base_pattern"
mlflow.set_tracking_uri(REMOTE_TRACKING_URI)

experiment = mlflow.get_experiment_by_name(experiment_name)
mlflow.set_experiment(experiment_id=experiment.experiment_id)
# Out:
# <Experiment: artifact_location='s3://kaggle-nakayama/mlflow/6', creation_time=1730853199485, experiment_id='6', last_update_time=1730853199485, lifecycle_stage='active', name='base_pattern', tags={}>

# %%
runs = mlflow.search_runs(experiment_ids=experiment.experiment_id)

# %%
flg = runs["tags.mlflow.runName"].str.contains("lenta")
run_df = runs.loc[flg]

# %%
run_df
# Out:
#                              run_id experiment_id    status  \
# 3  d6baa27d393d49ee9528b266d5c26702             6  FINISHED
# 4  d4165f1f586d4848bf143b3d2292dbbd             6  FINISHED
# 5  1c1f8f7e28784019b05fcdc4b9164604             6  FINISHED
# 6  764abaa22d9b4e28817e5e35ad195e36             6  FINISHED
# 7  0f74be1a364b4a7f92237a5261fe9d65             6  FINISHED
#
#                                         artifact_uri  \
# 3  s3://kaggle-nakayama/mlflow/6/d6baa27d393d49ee...
# 4  s3://kaggle-nakayama/mlflow/6/d4165f1f586d4848...
# 5  s3://kaggle-nakayama/mlflow/6/1c1f8f7e28784019...
# 6  s3://kaggle-nakayama/mlflow/6/764abaa22d9b4e28...
# 7  s3://kaggle-nakayama/mlflow/6/0f74be1a364b4a7f...
#
#                         start_time                         end_time  \
# 3 2024-11-10 11:48:13.406000+00:00 2024-11-10 11:50:51.012000+00:00
# 4 2024-11-10 11:45:46.058000+00:00 2024-11-10 11:48:12.511000+00:00
# 5 2024-11-10 11:34:28.415000+00:00 2024-11-10 11:45:45.165000+00:00
# 6 2024-11-10 11:30:39.946000+00:00 2024-11-10 11:34:27.567000+00:00
# 7 2024-11-10 11:26:26.265000+00:00 2024-11-10 11:30:39.046000+00:00
#
#    metrics.system/gpu_0_power_usage_percentage  metrics.qini_at_10  \
# 3                                         10.3          162.071535
# 4                                         10.2          196.332130
# 5                                         10.2          145.133886
# 6                                         10.2          200.108597
# 7                                         10.3           58.355031
#
#    metrics.qini_at_90  metrics.uplift_at_90  ...  tags.package  \
# 3          956.967352              0.010293  ...      causalml
# 4         1010.844166              0.010867  ...      causalml
# 5          868.496362              0.009351  ...      causalml
# 6          830.475590              0.008940  ...      causalml
# 7          929.616735              0.010011  ...      causalml
#
#    tags.mlflow.source.type  tags.mlflow.user  tags.sample  \
# 3                    LOCAL             admin         None
# 4                    LOCAL             admin         None
# 5                    LOCAL             admin         None
# 6                    LOCAL             admin         None
# 7                    LOCAL             admin         None
#
#                             tags.mlflow.note.content  tags.mlflow.runName  \
# 3  base_pattern: tlearner training and evaluation...       lenta_tlearner
# 4  base_pattern: slearner training and evaluation...       lenta_slearner
# 5  base_pattern: rlearner training and evaluation...       lenta_rlearner
# 6  base_pattern: xlearner training and evaluation...       lenta_xlearner
# 7  base_pattern: drlearner training and evaluatio...      lenta_drlearner
#
#               tags.mlflow.source.git.commit  tags.dataset  \
# 3  aa57897bc18443703e0d2d2a17ceebab3d52477c         lenta
# 4  aa57897bc18443703e0d2d2a17ceebab3d52477c         lenta
# 5  aa57897bc18443703e0d2d2a17ceebab3d52477c         lenta
# 6  aa57897bc18443703e0d2d2a17ceebab3d52477c         lenta
# 7  aa57897bc18443703e0d2d2a17ceebab3d52477c         lenta
#
#                        tags.mlflow.source.name  tags.model
# 3  /workspace/dev/process/model/metalearner.py    tlearner
# 4  /workspace/dev/process/model/metalearner.py    slearner
# 5  /workspace/dev/process/model/metalearner.py    rlearner
# 6  /workspace/dev/process/model/metalearner.py    xlearner
# 7  /workspace/dev/process/model/metalearner.py   drlearner
#
# [5 rows x 54 columns]

# %%
with mlflow.start_run(run_name="lenta", tags={"dataset": "lenta"}) as parent_run:
    pass
# Out:
# 2024/11/17 05:52:59 INFO mlflow.tracking._tracking_service.client: 🏃 View run lenta at: http://ec2-44-217-145-52.compute-1.amazonaws.com:5000/#/experiments/6/runs/0add35cfa1224f2995bffa12ae61e17b.
# 2024/11/17 05:52:59 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://ec2-44-217-145-52.compute-1.amazonaws.com:5000/#/experiments/6.
